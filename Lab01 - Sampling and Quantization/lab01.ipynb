# %% [markdown]
# **Processamento Digital de Imagens**
#
# Prática de Amostragem e Quantização
#
# Instruções:
# Utilize python e a biblioteca OpenCV para abertura das imagens.

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 1)	Utilizando imagem relogio.tif e faça uma reamostragem de seus pixels para 300, 150 e 72 dpi. Sabe-se que a imagem original possui 1250 dpi. Fazer os cálculos por meio do seu algortimo. Não usar o opencv para a conversão

# %%
# type your code here
# Python code to read image
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("relogio.tif", cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray', vmin=0, vmax=255);

print('Tamanho da imagem : ',img.shape)
# convertendo para 300dpi

linhas = img.shape[0]
colunas = img.shape[1];
# Out:
# Tamanho da imagem :  (3692, 2812)

# %%
#linhas/x = 300
#colunas
#2812 --- 1250*2.25
# ?   --- 300*2.25
dpi = 300
temp_linhas = int(linhas/((linhas*dpi)/1250))
temp_colunas = int(colunas/((colunas*dpi)/1250))
temp_img = img[0:linhas:temp_linhas,0:colunas:temp_colunas]
plt.imshow(temp_img, cmap='gray', vmin=0, vmax=255);

# %%
dpi = 150
temp_linhas = int(linhas/((linhas*dpi)/1250))
temp_colunas = int(colunas/((colunas*dpi)/1250))
temp_img = img[0:linhas:temp_linhas,0:colunas:temp_colunas]
plt.imshow(temp_img, cmap='gray', vmin=0, vmax=255);

# %%
dpi = 72
temp_linhas = int(linhas/((linhas*dpi)/1250))
temp_colunas = int(colunas/((colunas*dpi)/1250))
temp_img = img[0:linhas:temp_linhas,0:colunas:temp_colunas]
plt.imshow(temp_img, cmap='gray', vmin=0, vmax=255);

# %% [markdown]
# 2)	Utilizando a imagem ctskull-256.tif, refaça a quantização de seus pixels utilizando de 7 a 1 bit(s) por pixel.  Fazer os cálculos por meio do seu algortimo. Não usar o opencv para a conversão

# %%
img = cv2.imread("ctskull-256.tif", cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray', vmin=0, vmax=255);

linhas = img.shape[0]
colunas = img.shape[1];
# Out:
# Tamanho da imagem :  (452, 374)

# %%
# 256 levels - values between 0 - 255 
# 128 levels - 
# (A % (128 * 2))-1 
def new_image(levels, img):
    #values between 0 - 1
    max = np.power(2,levels)
    temp = img / 256
    temp = np.round(temp * (max-1))
    temp = np.round(temp * (256/(max-1)))
    return temp
aux_img = new_image(8, img)
plt.imshow(aux_img, cmap='gray', vmin=0, vmax=255)

# %%
plt.figure()
#subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(2,4) 

# use the created array to output your multiple images. In this case I have stacked 4 images vertically
axarr[0,0].imshow(new_image(8, img), cmap='gray')
axarr[0,1].imshow(new_image(7, img), cmap='gray')
axarr[0,2].imshow(new_image(6, img))
axarr[0,3].imshow(new_image(5, img))
axarr[1,0].imshow(new_image(4, img))
axarr[1,1].imshow(new_image(3, img))
axarr[1,2].imshow(new_image(2, img))
axarr[1,3].imshow(new_image(1, img))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[97], line 3
#       1 plt.figure()
#       2 #subplot(r,c) provide the no. of rows and columns
# ----> 3 f, axarr = plt.subplots(2,4, cmap='gray')
#       5 # use the created array to output your multiple images. In this case I have stacked 4 images vertically
#       6 axarr[0,0].imshow(new_image(8, img))
#
# File c:\Users\Luis\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1501, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1355 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1356              width_ratios=None, height_ratios=None,
#    1357              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1358     """
#    1359     Create a figure and a set of subplots.
#    1360
# ...

# %%
np.max(aux_img)
# Out:
# 4.0
